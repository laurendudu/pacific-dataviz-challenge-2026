# %%
from pyaesa import set_workspace, download_pop_gdp, download_mrio, download_ar6
# Out:
# Workspace setup guidance information is available in:
# /Users/laurendurivault/Documents/GitHub/laurendudu/pacific-dataviz-challenge-2026/data_raw/summary.log

# %%
# 1. Initialize workspace (always first, every session)
set_workspace(top_path="/Users/laurendurivault/Documents/GitHub/laurendudu/pacific-dataviz-challenge-2026")

# %%
download_pop_gdp()
# Out:
# Downloading SSP Population and GDP PPP data for years 2025-2100
# Downloaded SSP raw CSV to:
# /Users/laurendurivault/Documents/GitHub/laurendudu/pacific-dataviz-challenge-2026/data_raw/pop_gdp/ssp_raw.csv

# %%
pyaesa.download_ar6()
# Out:
# <pre>Downloading AR6 public explorer data (1/4)</pre>
# [ar6-public] Summary:
#   Raw data folder: /Users/laurendurivault/Documents/GitHub/laurendudu/pacific-dataviz-challenge-2026/data_raw/carrying_capacities/dynamic_climate_change_ar6
#   Logs folder: /Users/laurendurivault/Documents/GitHub/laurendudu/pacific-dataviz-challenge-2026/data_raw/logs
#   Errors: 1 asset(s)
#   See report.errors for details.
